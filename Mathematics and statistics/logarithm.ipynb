# %%
import pandas as pd
df = pd.read_csv("C:/Users/vamsh/OneDrive/Desktop/MACHINE LEARNING/Mathematics and statistics/revenue.csv")
df.head()
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6

# %%
import matplotlib.pyplot as plt

df.plot(x='company',y='revenue',kind='bar', logy=True)
# Out:
# <Axes: xlabel='company'>

# %%
df2 = pd.read_csv("C:/Users/vamsh/OneDrive/Desktop/MACHINE LEARNING/Mathematics and statistics/income (2).csv")
df2.head()
# Out:
#    income($)  count
# 0       5000   4371
# 1      10000   3295
# 2      15000   5825
# 3      20000   6047
# 4      25000   6097

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize':(11.7,8.27)})
g = sns.barplot(x='income($)',y='count',data=df2)
g.set_xticklabels(g.get_xticklabels(),
                  rotation=45,
                  horizontalalignment='right')
# Out:
# C:\Users\vamsh\AppData\Local\Temp\ipykernel_22684\3757523014.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(),
# [Text(0, 0, '5000'),
#  Text(1, 0, '10000'),
#  Text(2, 0, '15000'),
#  Text(3, 0, '20000'),
#  Text(4, 0, '25000'),
#  Text(5, 0, '30000'),
#  Text(6, 0, '35000'),
#  Text(7, 0, '40000'),
#  Text(8, 0, '45000'),
#  Text(9, 0, '50000'),
#  Text(10, 0, '55000'),
#  Text(11, 0, '60000'),
#  Text(12, 0, '65000'),
#  Text(13, 0, '70000'),
#  Text(14, 0, '75000'),
#  Text(15, 0, '80000'),
#  Text(16, 0, '85000'),
#  Text(17, 0, '90000'),
#  Text(18, 0, '95000'),
#  Text(19, 0, '100000'),
#  Text(20, 0, '105000'),
#  Text(21, 0, '110000'),
#  Text(22, 0, '115000'),
#  Text(23, 0, '120000'),
#  Text(24, 0, '125000'),
#  Text(25, 0, '130000'),
#  Text(26, 0, '135000'),
#  Text(27, 0, '140000'),
#  Text(28, 0, '145000'),
#  Text(29, 0, '150000'),
# ...

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize':(11.7,8.27)})
g = sns.barplot(x='income($)',y='count',data=df2)
g.set_xticklabels(g.get_xticklabels(),
                  rotation=45,
                  horizontalalignment='right')

g.set(xscale="log")
# Out:
# C:\Users\vamsh\AppData\Local\Temp\ipykernel_22684\1363663209.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(),
# [None]
